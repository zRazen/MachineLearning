# %%
# !pip install Flask pyngrok line-bot-sdk requests --quiet
# !pip install google-genai --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 819.5/819.5 kB 23.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 165.6/165.6 kB 8.6 MB/s eta 0:00:00

# %%
from google.colab import userdata

ngrok_authtoken = userdata.get('NGROK_AUTHTOKEN')
line_channel_access_token = userdata.get('LINE_CHANNEL_ACCESS_TOKEN')
line_channel_secret = userdata.get('LINE_CHANNEL_SECRET')
gemini_api_key = userdata.get('GEMINI_API_KEY')
port = 5051

# %%
import os
from pyngrok import ngrok

# %%
ngrok.kill()

# %%
import requests

ngrok.set_auth_token(ngrok_authtoken)
tunnel = ngrok.connect(5051, name="linebot_tunnel")
webhook_url = tunnel.public_url

print(f"Ngrok URL: {webhook_url}")

# 自動更新 LINE Webhook URL
def update_line_webhook(webhook_url):
    """使用 LINE Messaging API 更新 Webhook URL"""
    url = "https://api.line.me/v2/bot/channel/webhook/endpoint"
    headers = {
        "Authorization": f"Bearer {line_channel_access_token}",
        "Content-Type": "application/json"
    }
    data = {
        "endpoint": webhook_url
    }

    response = requests.put(url, headers=headers, json=data)

    if response.status_code == 200:
        print(f"✅ LINE Webhook URL 已自動更新為：{webhook_url}")
        return True
    else:
        print(f"❌ 更新失敗：{response.status_code} - {response.text}")
        return False

# 執行更新
update_line_webhook(webhook_url)
# Out:
# Ngrok URL: https://baritone-scarily-unmade.ngrok-free.dev
# ✅ LINE Webhook URL 已自動更新為：https://baritone-scarily-unmade.ngrok-free.dev
# True

# %%
from google import genai

client = genai.Client(api_key=gemini_api_key)

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="什麼是AI AGENT？"
)
print(response.text)
# Out:
# AI Agent（人工智慧代理）是一個近期越來越熱門，但概念其實存在已久的詞彙。它指的是一個能夠在特定環境中**感知（Perceive）**、**推理（Reason）**、**決策（Decide）**並**執行（Act）**，以達成特定目標的人工智慧系統。
#
# 簡單來說，你可以把AI Agent想像成一個擁有「大腦」（AI模型）和「手腳」（執行工具）的自動化助手。它不需要人類每一步的指導，而是能根據當前情況自主判斷並採取行動。
#
# ### AI Agent 的核心要素：
#
# 1.  **感知 (Perception)**：
#     *   AI Agent 需要從其操作的環境中收集資訊。這可以是透過感測器（如攝影機、麥克風）、程式介面（API）接收數據、讀取文件、監聽網路事件等。
#     *   **例子**：一個自動駕駛汽車的AI Agent會感知道路狀況、交通號誌、其他車輛和行人。一個線上客服AI Agent會感知用戶輸入的問題。
#
# 2.  **推理與決策 (Reasoning & Decision-making)**：
#     *   在感知到環境資訊後，AI Agent 會利用其內建的智慧（例如大型語言模型LLM、規則引擎、機器學習模型等）來處理這些資訊，理解當前情況，並決定下一步的最佳行動。
#     *   **例子**：自動駕駛汽車的AI Agent會判斷是否需要加速、減速或轉彎。客服AI Agent會判斷用戶問題的意圖並尋找相關答案。
#
# 3.  **執行 (Action)**：
#     *   根據決策，AI Agent 會執行一系列操作來影響其環境，以實現預設的目標。這可以是實體動作（如移動機器人手臂）、發送指令（如控制智慧家電）、生成文字（如回覆訊息）或呼叫外部工具（如API）。
#     *   **例子**：自動駕駛汽車的AI Agent會控制方向盤、油門和剎車。客服AI Agent會生成回答文本、或是呼叫訂單查詢API來獲取資訊。
#
# 4.  **目標 (Goal)**：
#     *   每個AI Agent 都會被設定一個或多個明確的目標。所有的感知、推理和執行都圍繞著這個目標進行。
#     *   **例子**：自動駕駛汽車的目標是安全、高效地將乘客從A點運送到B點。客服AI Agent的目標是準確、快速地解決用戶問題。
#
# 5.  **環境 (Environment)**：
#     *   AI Agent 總是在一個特定的環境中運作，這個環境可以是物理世界（如機器人）、數位世界（如網路應用、軟體系統）或兩者的結合。
#     *   **例子**：自動駕駛汽車的環境是真實的道路和交通。客服AI Agent的環境是數位通訊平台和後端資料庫。
#
# ### AI Agent 的特點：
#
# *   **自主性 (Autonomy)**：這是AI Agent 最重要的特點。它能獨立運作，不需要人類持續的指令或監督。
# *   **反應性 (Reactivity)**：能夠即時響應環境的變化。
# *   **主動性 (Pro-activeness)**：不只是被動響應，還能主動採取行動來達成目標。
# *   **社交性 (Sociality - 某些Agent)**：能夠與其他Agent或人類進行溝通和協作。
# *   **學習能力 (Learning - 某些Agent)**：能夠從經驗中學習，改進其性能。
#
# ### 實際應用範例：
#
# *   **智能客服/虛擬助手**：Siri、Alexa、Google Assistant 雖然是常見的虛擬助手，但更進階的AI Agent 可以不只理解指令，還能自主執行多步驟任務，例如「幫我安排週末的旅行計畫」。
# *   **自動駕駛汽車**：車輛本身就是一個巨大的AI Agent，感知路況、決策行駛、執行操作。
# *   **自動化交易機器人**：監測市場數據（感知），分析趨勢（推理），自主買賣股票/加密貨幣（執行），目標是獲利。
# *   **智能家居系統**：恆溫器根據室內外溫度（感知）和用戶偏好（目標）自動調節冷暖氣（執行）。
# *   **個人生產力助手**：一個AI Agent 可以幫你管理電子郵件、日程，甚至自動草擬文件。
# *   **遊戲中的NPC (Non-Player Character)**：這些角色在遊戲世界中感知環境、做出行為，以模擬真實角色。
#
# 隨著大型語言模型（LLMs）的發展，AI Agent 的能力得到了極大提升，因為LLMs為Agent提供了強大的「大腦」來理解複雜指令、進行多步驟推理和生成行動計畫，使得開發更複雜、更自主的AI Agent成為可能。

# %%
def stateless_query(payload):
    response = client.models.generate_content(
        model="gemini-2.5-flash",
        contents=payload
    )
    return response.text

# %%
result = stateless_query("簡介明新科技大學")
print(result)
# Out:
# 明新科技大學（Ming Hsin University of Science and Technology, MHUST）位於台灣科技重鎮新竹縣，是一所歷史悠久、以培養實務應用人才為導向的私立科技大學。
#
# 以下是其簡要介紹：
#
# 1.  **創校歷史與沿革：** 學校創立於1966年，前身為「明新工業專科學校」。隨著台灣產業升級與教育發展趨勢，於1997年改制為技術學院，並於2002年正式升格為「明新科技大學」。深耕技職教育逾半世紀，擁有豐富的辦學經驗。
#
# 2.  **地理位置優勢：** 明新科技大學緊鄰新竹科學園區，受惠於周邊高科技產業的發展，與在地企業建立了緊密的產學合作關係，為學生提供了豐富的實習和就業機會。
#
# 3.  **學術架構與特色：**
#     *   **學院設置：** 目前設有工程學院、管理學院、服務事業與設計學院等，提供學士、碩士等多元學制。
#     *   **教學重心：** 其教學與研究重心涵蓋了傳統的工程技術、資訊科技、企業管理，以及新興的觀光休閒、數位設計等領域。
#     *   **實務致用：** 學校特別強調「產學合作」與「實務致用」，透過實習、建教合作、證照輔導、競賽參與等方式，提升學生的專業技能與職場競爭力，旨在培養具備「即戰力」的專業人才。
#     *   **創新創業：** 鼓勵學生創新思考與創業，提供相關資源與輔導。
#
# 4.  **辦學理念：** 以「誠信、創新、服務」為核心價值，致力於提供優質的教學環境與設備，培養學生具備專業技能、人文素養及國際視野，期望成為國家產業發展的重要推手。
#
# 總體而言，明新科技大學憑藉其深厚的辦學經驗、緊密的產學鏈結以及位於科技核心區位的優勢，持續為社會培育符合產業需求、具備專業技能與人文素養的現代科技人才。

# %%
from flask import Flask, request, abort

from linebot.v3 import (
    WebhookHandler
)
from linebot.v3.exceptions import (
    InvalidSignatureError
)
from linebot.v3.messaging import (
    Configuration,
    ApiClient,
    MessagingApi,
    ReplyMessageRequest,
    TextMessage,
)
from linebot.v3.webhooks import (
    MessageEvent,
    TextMessageContent,
)

app = Flask(__name__)

configuration = Configuration(access_token=line_channel_access_token)
handler = WebhookHandler(line_channel_secret)


@app.route("/", methods=['POST'])
def callback():
    # get X-Line-Signature header value
    signature = request.headers['X-Line-Signature']

    # get request body as text
    body = request.get_data(as_text=True)
    print("BODY: ", body)
    app.logger.info("Request body: " + body)

    # handle webhook body
    try:
        handler.handle(body, signature)
    except InvalidSignatureError:
        app.logger.info("Invalid signature. Please check your channel access token/channel secret.")
        abort(400)

    return 'OK'


@handler.add(MessageEvent, message=TextMessageContent)
def handle_message(event):
    text = event.message.text
    with ApiClient(configuration) as api_client:
        line_bot_api = MessagingApi(api_client)
        if text.startswith('AI '): #判斷輸入前三個字是不是AI
            prompt = text[3:]
            reply_text = stateless_query(prompt)
            line_bot_api.reply_message_with_http_info(
                ReplyMessageRequest(
                    reply_token=event.reply_token,
                    messages=[TextMessage(text=reply_text)]
                )
            )

        else:
            line_bot_api.reply_message_with_http_info(
                ReplyMessageRequest(
                    reply_token=event.reply_token,
                    messages=[TextMessage(text=event.message.text),
                        TextMessage(text=event.message.text)]
                )
            )

if __name__ == "__main__":
    app.run(port=port)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5051
# INFO:werkzeug:Press CTRL+C to quit
# BODY:  {"destination":"U119d07e95858d5d83008458c2d433c76","events":[{"type":"message","message":{"type":"text","id":"616073655843029198","quoteToken":"t0KRT_-vQr49UoNiZRV5nm_GMzz9rLsJsJQWY2oaKuVfrHN7lb_nIpeelbfLz0lr97KfnjKxH7itllOn1jDoDCUF86fsAYwBiLMEsP-DbXUERkadNTGNrHswypKPmHrUJKiD9WghQV6JkmSM0aji8Q","markAsReadToken":"bqKqz9zsJOtN-iw3a9-zo6FrIyZpai-MkaZRQcht2KHOYK_yyHlyTrc7Y7D8JUBi6hNSiHiPT2k0QyKuzjTi8C5dc-qar8yhM2rlZbKLrJi22De79J-1q9I7PTopaVg8QU_F5ylo-6jFUrXo_fG4fK0mi-qhE64Kmy9KY2yZ2NJFn9R013Pj9GNZJ9-MPizzNeg65LJS2zmO0TF7oJc0CQ","text":"簡介明新科技大學"},"webhookEventId":"01KSSA876FCHDK117QGREFE1QT","deliveryContext":{"isRedelivery":false},"timestamp":1780039818201,"source":{"type":"user","userId":"U3d0a7956380119affa33de4fb575bbcb"},"replyToken":"7400e77c507c4414bb6d5639d3a42f45","mode":"active"}]}
# INFO:werkzeug:127.0.0.1 - - [29/May/2026 07:30:19] "POST / HTTP/1.1" 200 -
# BODY:  {"destination":"U119d07e95858d5d83008458c2d433c76","events":[{"type":"message","message":{"type":"text","id":"616073675708039630","quoteToken":"90A3Kdo47Eqom_RJ2PQ0L5Tltskbh9hU4FEnSWFYSz0Fq0LGgWOEhoECRba2zuavw81Ur35OINi2pB-hlwJ8yb4fwKf7MjyYA5j1rZIKoWu130ZuBa2MmOQFEmwHOOgTtA3dJ6Aat1Fzw4PUwsF6-w","markAsReadToken":"w0q5dnUl4XP5ARNjW5sghHJm26uk1f-4T31_ELmMVCNAzQlAbUk5K_1FQwPzJdnrKvwO1oRPNF62ksIZA_5FzCTkciOaZzxrdqVY02a5JZxBhVnIEpI-C1VTp0ET1_rHRBhkU8CYDewK4irQjyWLI1VUGwniZ46TOhbyFiLbPUf94tkc_yNQ11XHDKnkyWB49sUPZ__4ZCOJktto5Z0WhQ","text":"AI 簡介明新科技大學"},"webhookEventId":"01KSSA8JZXR6VTH4CHDTTP2K6H","deliveryContext":{"isRedelivery":false},"timestamp":1780039830016,"source":{"type":"user","userId":"U3d0a7956380119affa33de4fb575bbcb"},"replyToken":"6899ad6070534623a9118cb8e152101b","mode":"active"}]}
# INFO:werkzeug:127.0.0.1 - - [29/May/2026 07:30:42] "POST / HTTP/1.1" 200 -
# WARNING:pyngrok.process.ngrok:t=2026-05-29T07:31:18+0000 lvl=warn msg="Stopping forwarder" name=linebot_tunnel acceptErr="failed to accept connection: Listener closed"
